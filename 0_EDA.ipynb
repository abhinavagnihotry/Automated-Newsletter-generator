# %%
# 0) Setup
from datasets import load_dataset
import pandas as pd
import pytz, re, math
from datetime import datetime, timedelta
from urllib.parse import urlsplit, urlunsplit, parse_qsl, urlencode
from sentence_transformers import SentenceTransformer
import numpy as np

# %%
IST = pytz.timezone("Asia/Kolkata")
model = SentenceTransformer("all-MiniLM-L6-v2")

# 1) Ingest
ds = load_dataset("zenml/llmops-database")["train"].to_pandas()
df = ds.copy()

# %%
# --- Setup ---
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# --- Load dataset ---
# This pulls directly from Hugging Face Hub
dataset = load_dataset("zenml/llmops-database")

# Convert the 'train' split into pandas DataFrame
df = dataset["train"].to_pandas()

# %%
df.head(5)  # Display the first few rows of the DataFrame
# Out:
#                  created_at  \
# 0  2025-09-09T07:46:00.000Z
# 1  2025-09-09T07:42:00.000Z
# 2  2025-09-09T07:39:00.000Z
# 3  2025-09-08T09:00:00.000Z
# 4  2025-09-08T08:14:00.000Z
#
#                                                title               industry  \
# 0  Natural Language Analytics Assistant Using Ama...  Media & Entertainment
# 1  AI-Powered Hyper-Personalized Email Campaign A...                   Tech
# 2  Claude Code Agent Architecture: Single-Threade...                   Tech
# 3  Dynamic Prompt Injection for Reliable AI Agent...                   Tech
# 4  Enterprise RAG System with Coveo Passage Retri...                   Tech
#
#      year                                         source_url        company  \
# 0  2025.0  https://aws.amazon.com/blogs/machine-learning/...           skai
# 1  2025.0  https://blog.promptlayer.com/ai-sales-engineer...    promptlayer
# 2  2025.0  https://blog.promptlayer.com/claude-code-behin...      anthropic
# 3  2025.0  https://www.controlpla.in/blog/prompt-injectio...  control_plain
# 4  2025.0  https://aws.amazon.com/blogs/machine-learning/...          coveo
#
#                                     application_tags  \
# 0  data_analysis,question_answering,chatbot,data_...
# 1  customer_support,content_moderation,classifica...
# 2                code_generation,code_interpretation
# 3                           customer_support,chatbot
# 4  question_answering,document_processing,custome...
#
#                                           tools_tags  \
# 0  monitoring,api_gateway,orchestration,scaling,s...
# 1       fastapi,open_source,documentation,monitoring
# 2  docker,monitoring,security,guardrails,reliabil...
# 3                  reliability,compliance,guardrails
# 4  serverless,api_gateway,monitoring,databases,se...
#
#                                           extra_tags  \
# 0  amazon bedrock agents,natural language process...
# 1  prompt engineering,ai agents,email automation,...
# 2  agent architecture,single threaded loop,tool o...
# 3  prompt engineering,ai agents,production deploy...
# 4  rag,retrieval augmented generation,amazon bedr...
#
#                                      techniques_tags  \
# 0  rag,prompt_engineering,multi_agent_systems,age...
# 1  prompt_engineering,multi_agent_systems,agent_b...
# 2  prompt_engineering,multi_agent_systems,agent_b...
# 3  prompt_engineering,few_shot,semantic_search,ag...
# 4  rag,embeddings,semantic_search,vector_search,p...
#
#                                        short_summary  \
# 0  Skai, an omnichannel advertising platform, dev...
# 1  PromptLayer built an automated AI sales system...
# 2  Anthropic's Claude Code implements a productio...
# 3  Control Plain addressed the challenge of unrel...
# 4  Coveo addresses the challenge of LLM accuracy ...
#
#                                         full_summary
# 0  # Skai: Natural Language Analytics Assistant U...
# 1  # PromptLayer: AI-Powered Hyper-Personalized E...
# 2  # Anthropic: Claude Code Agent Architecture: S...
# 3  # Control Plain: Dynamic Prompt Injection for ...
# 4  # Coveo: Enterprise RAG System with Coveo Pass...

# %%
# --- Quick look at data ---
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
# Out:
# Shape: (907, 12)
#
# Columns: ['created_at', 'title', 'industry', 'year', 'source_url', 'company', 'application_tags', 'tools_tags', 'extra_tags', 'techniques_tags', 'short_summary', 'full_summary']

# %%
# --- Basic info ---
print("\nData types:")
print(df.dtypes)
# Out:
# Data types:
# created_at           object
# title                object
# industry             object
# year                float64
# source_url           object
# company              object
# application_tags     object
# tools_tags           object
# extra_tags           object
# techniques_tags      object
# short_summary        object
# full_summary         object
# dtype: object

# %%
print("\nMissing values:")
print(df.isna().sum())
# Out:
# Missing values:
# created_at           0
# title                0
# industry             0
# year                95
# source_url           1
# company              0
# application_tags     0
# tools_tags           0
# extra_tags           0
# techniques_tags      0
# short_summary        0
# full_summary         0
# dtype: int64

# %%
# --- Created_at field analysis ---
df["created_at"] = pd.to_datetime(df["created_at"], errors="coerce")
df["year_week"] = df["created_at"].dt.to_period("W")

# Count by month
monthly_counts = df["year_week"].value_counts().sort_index()
monthly_counts.plot(kind="bar", figsize=(12,4))
plt.title("Number of items per week")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/qw/kndrzd253bbb5qrt4cz3wxqr0000gn/T/ipykernel_95284/3093001556.py:3: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["year_week"] = df["created_at"].dt.to_period("W")

# %%
# --- Check for duplicates ---
print("\nShape before removing duplicates:", df.shape)
# By title
dup_titles = df[df.duplicated("title", keep=False)].sort_values(["title", "created_at"])
print("Number of duplicate titles:", dup_titles["title"].nunique())
# print("Sample duplicate titles:\n", dup_titles[["title", "created_at", "source_url"]].head(10))

# By source_url
dup_urls = df[df.duplicated("source_url", keep=False)].sort_values(["source_url", "created_at"])
print("Number of duplicate URLs:", dup_urls["source_url"].nunique())
# print("Sample duplicate URLs:\n", dup_urls[["title", "created_at", "source_url"]].head(10))

# --- Remove duplicates ---
df = df.sort_values("created_at").drop_duplicates(subset=["title"], keep="last")
df = df.sort_values("created_at").drop_duplicates(subset=["source_url"], keep="last")

print("\nShape after removing duplicates:", df.shape)
# Out:
# Shape before removing duplicates: (907, 13)
# Number of duplicate titles: 2
# Number of duplicate URLs: 10
#
# Shape after removing duplicates: (896, 13)

# %%
df["industry"].value_counts()
# Out:
# industry
# Tech                     480
# Finance                   82
# E-commerce                79
# Healthcare                58
# Media & Entertainment     47
# Insurance                 20
# Other                     19
# Education                 16
# Automotive                16
# Consulting                15
# Government                14
# Telecommunications        13
# Legal                     13
# Energy                     8
# Research & Academia        8
# HR                         7
#                            1
# Name: count, dtype: int64

# %%
industries_of_interest = ["Tech", "Telecommunications", "Research & Academia"]

# %%
filtered_df = df[df["industry"].isin(industries_of_interest)]
filtered_df.shape
filtered_df.head()  # Display the first few rows of the filtered dataframe
# Out:
#                    created_at  \
# 906 2024-07-10 14:21:00+00:00
# 904 2024-07-10 14:21:00+00:00
# 903 2024-07-10 14:38:00+00:00
# 902 2024-07-10 14:39:00+00:00
# 901 2024-07-31 13:30:00+00:00
#
#                                                  title industry    year  \
# 906  LLM Validation and Testing at Scale: GitLab's ...     Tech  2024.0
# 904  Building a Scalable Retriever-Ranker Architect...     Tech  2024.0
# 903  Building Secure and Private Enterprise LLM Inf...     Tech  2024.0
# 902   Building and Scaling LLM Applications at Discord     Tech  2024.0
# 901  Optimizing Text-to-SQL Pipeline Using Agent Ex...     Tech  2024.0
#
#                                             source_url    company  \
# 906  https://about.gitlab.com/blog/2024/05/09/devel...     gitlab
# 904  https://blog.malt.engineering/super-powering-o...       malt
# 903  https://slack.engineering/how-we-built-slack-a...      slack
# 902  https://discord.com/blog/developing-rapidly-wi...    discord
# 901  https://idinsight.github.io/tech-blog/blog/aam...  idinsight
#
#                                       application_tags  \
# 906  code_generation,high_stakes_application,regula...
# 904             structured_output,realtime_application
# 903    regulatory_compliance,legacy_system_integration
# 902  chatbot,content_moderation,structured_output,r...
# 901                   question_answering,data_analysis
#
#                                             tools_tags  \
# 906  monitoring,cicd,devops,continuous_deployment,c...
# 904  kubernetes,monitoring,scaling,devops,orchestra...
# 903  security,compliance,guardrails,reliability,sca...
# 902  monitoring,scaling,devops,security,compliance,...
# 901   fastapi,crewai,databases,scalability,reliability
#
#                                             extra_tags  \
# 906  llm,testing,evaluation,prompt engineering,metr...
# 904  recommenders,rerankers,vector database,qdrant,...
# 903  rag,aws,sagemaker,security,privacy,compliance,...
# 902  prompt engineering,evaluation,deployment,safet...
# 901  text to sql,llm,crewai,fastapi,rag,prompt engi...
#
#                                        techniques_tags  \
# 906  prompt_engineering,error_handling,latency_opti...
# 904  embeddings,semantic_search,vector_search,model...
# 903  rag,semantic_search,error_handling,latency_opt...
# 902  prompt_engineering,fine_tuning,model_optimizat...
# 901  rag,prompt_engineering,multi_agent_systems,mod...
#
#                                          short_summary  \
# 906  GitLab developed a robust framework for valida...
# 904  Malt's implementation of a retriever-ranker ar...
# 903  Slack implemented AI features by developing a ...
# 902  Discord shares their comprehensive approach to...
# 901  Ask-a-Metric developed a WhatsApp-based AI dat...
#
#                                           full_summary              year_week
# 906  # Gitlab: LLM Validation and Testing at Scale:...  2024-07-08/2024-07-14
# 904  # Malt: Building a Scalable Retriever-Ranker A...  2024-07-08/2024-07-14
# 903  # Slack: Building Secure and Private Enterpris...  2024-07-08/2024-07-14
# 902  # Discord: Building and Scaling LLM Applicatio...  2024-07-08/2024-07-14
# 901  # IDInsight: Optimizing Text-to-SQL Pipeline U...  2024-07-29/2024-08-04

# %%
# --- Top industries ---
plt.figure(figsize=(8,4))
filtered_df["industry"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Industries in Dataset")
plt.ylabel("Count")
plt.show()

# %%
# --- Top companies mentioned ---
plt.figure(figsize=(8,4))
filtered_df["company"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Companies in Dataset")
plt.ylabel("Count")
plt.show()

# %%
# save the dataframe to a csv file
filtered_df.to_csv("filtered_llmops_database.csv", index=False)
